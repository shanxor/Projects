# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
house = pd.read_csv('/content/home_data.csv')

# %%
house.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
house.drop(['id','date','grade'],axis=1,inplace=True)

# %%
house.bedrooms.value_counts()
# Out:
# bedrooms
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: count, dtype: int64

# %%
house.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition    sqft_above  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430   1788.390691
# ...

# %%
house[['sqft_basement', 'price']].corr()
# Out:
#                sqft_basement     price
# sqft_basement       1.000000  0.323816
# price               0.323816  1.000000

# %%
plt.scatter(house['sqft_living'], house['price'])
plt.xlabel('sqft of house')
plt.ylabel('price of houe')
# Out:
# Text(0, 0.5, 'price of houe')

# %%
house.isnull().sum()/len(house)*100
# Out:
# price            0.0
# bedrooms         0.0
# bathrooms        0.0
# sqft_living      0.0
# sqft_lot         0.0
# floors           0.0
# waterfront       0.0
# view             0.0
# condition        0.0
# sqft_above       0.0
# sqft_basement    0.0
# yr_built         0.0
# yr_renovated     0.0
# zipcode          0.0
# lat              0.0
# long             0.0
# sqft_living15    0.0
# sqft_lot15       0.0
# dtype: float64

# %%
house .columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15',
#        'sqft_lot15'],
#       dtype='object')

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21613 non-null  int64
#  1   bedrooms       21613 non-null  int64
#  2   bathrooms      21613 non-null  float64
#  3   sqft_living    21613 non-null  int64
#  4   sqft_lot       21613 non-null  int64
#  5   floors         21613 non-null  float64
#  6   waterfront     21613 non-null  int64
#  7   view           21613 non-null  int64
#  8   condition      21613 non-null  int64
#  9   sqft_above     21613 non-null  int64
#  10  sqft_basement  21613 non-null  int64
#  11  yr_built       21613 non-null  int64
#  12  yr_renovated   21613 non-null  int64
#  13  zipcode        21613 non-null  int64
#  14  lat            21613 non-null  float64
#  15  long           21613 non-null  float64
#  16  sqft_living15  21613 non-null  int64
# ...

# %%
house['bathrooms'] = house['bathrooms'].astype('category')
house['bathrooms'] = house['bathrooms'].cat.codes

# %%
house['floors'] = house['floors'].astype('category')
house['floors'] = house['floors'].cat.codes

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21613 non-null  int64
#  1   bedrooms       21613 non-null  int64
#  2   bathrooms      21613 non-null  int8
#  3   sqft_living    21613 non-null  int64
#  4   sqft_lot       21613 non-null  int64
#  5   floors         21613 non-null  int8
#  6   waterfront     21613 non-null  int64
#  7   view           21613 non-null  int64
#  8   condition      21613 non-null  int64
#  9   sqft_above     21613 non-null  int64
#  10  sqft_basement  21613 non-null  int64
#  11  yr_built       21613 non-null  int64
#  12  yr_renovated   21613 non-null  int64
#  13  zipcode        21613 non-null  int64
#  14  lat            21613 non-null  float64
#  15  long           21613 non-null  float64
#  16  sqft_living15  21613 non-null  int64
#  17  sqft_lot15     21613 non-null  int64
# ...

# %%
def boxplots(col):
    sns.boxplot(house[col])
    plt.show()

for i in list(house.select_dtypes(exclude=['object']).columns)[0:]:
    boxplots(i)

# %%
house.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15',
#        'sqft_lot15'],
#       dtype='object')

# %%
cols=['sqft_living', 'sqft_above', 'sqft_basement', 'sqft_living15', 'sqft_lot15']

# %%
# def outlier_treatment(cols):
#     for i in cols:
#         q1=house[i].quantile(0.25)
#         q3=house[i].quantile(0.75)
#         iqr=q3-q1
#         upper_limit=q3+(1.5*iqr)
#         lower_limit=q1-(1.5*iqr)
#         house[i]=np.where(house[i]>upper_limit,upper_limit,np.where(house[i]<lower_limit,lower_limit,house[i]))

# %%
#outlier_treatment(cols)

# %%
#def boxplots(col):
    #sns.boxplot(house[col])
    #plt.show()

#for i in list(house.select_dtypes(exclude=['object']).columns)[0:]:
    #boxplots(i)

# %%
house.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      7.459122   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      3.076836    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      6.000000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      8.000000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      9.000000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000     29.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition    sqft_above  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       0.988618      0.007542      0.234303      3.409430   1788.390691
# ...

# %%
x=house.drop(['price'],axis=1)
y=house['price']

# %%
x.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3          3         1180      5650       0           0     0
# 1         3          8         2570      7242       2           0     0
# 2         2          3          770     10000       0           0     0
# 3         4         11         1960      5000       0           0     0
# 4         3          7         1680      8080       0           0     0
#
#    condition  sqft_above  sqft_basement  yr_built  yr_renovated  zipcode  \
# 0          3        1180              0      1955             0    98178
# 1          3        2170            400      1951          1991    98125
# 2          3         770              0      1933             0    98028
# 3          5        1050            910      1965             0    98136
# 4          3        1680              0      1987             0    98074
#
#        lat     long  sqft_living15  sqft_lot15
# ...

# %%
y.head()
# Out:
# 0    221900
# 1    538000
# 2    180000
# 3    604000
# 4    510000
# Name: price, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaler = scaler.fit_transform(x)

# %%
pd.DataFrame(x_scaler).head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.398737 -1.449289 -0.979835 -0.228321 -0.915427 -0.087173 -0.305759
# 1 -0.398737  0.175794  0.533634 -0.189885  0.936506 -0.087173 -0.305759
# 2 -1.473959 -1.449289 -1.426254 -0.123298 -0.915427 -0.087173 -0.305759
# 3  0.676485  1.150844 -0.130550 -0.244014 -0.915427 -0.087173 -0.305759
# 4 -0.398737 -0.149222 -0.435422 -0.169653 -0.915427 -0.087173 -0.305759
#
#          7         8         9         10        11        12        13  \
# 0 -0.629187 -0.734708 -0.658681 -0.544898 -0.210128  1.870152 -0.352572
# 1 -0.629187  0.460841  0.245141 -0.681079  4.746678  0.879568  1.161568
# 2 -0.629187 -1.229834 -0.658681 -1.293892 -0.210128 -0.933388  1.283537
# 3  2.444294 -0.891699  1.397515 -0.204446 -0.210128  1.085160 -0.283288
# 4 -0.629187 -0.130895 -0.658681  0.544548 -0.210128 -0.073636  0.409550
#
#          14        15        16
# 0 -0.306079 -0.943355 -0.260715
# 1 -0.746341 -0.432686 -0.187868
# ...

# %%
# Calculate correlation matrix
corr = house.corr()

# Create a mask to hide the upper triangle (optional but helps reduce clutter)
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the figure
plt.figure(figsize=(12, 7))

# Create heatmap
sns.heatmap(
    corr,
    mask=mask,
    annot=True,
    fmt=".2f",
    cmap='coolwarm',
    square=True,
    linewidths=0.5,
    cbar_kws={"shrink": 0.8},
    annot_kws={"size": 9}
)

# Add title and tweak labels
plt.title("Correlation Heatmap", fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

variable = x_scaler

vif = pd.DataFrame()

vif['Variance Inflation Factor'] = [variance_inflation_factor(variable, i)
                                    for i in range(variable.shape[1])]

vif['Features'] = x.columns

# %%
vif
# Out:
#     Variance Inflation Factor       Features
# 0                    1.599235       bedrooms
# 1                    2.895164      bathrooms
# 2                    8.078317    sqft_living
# 3                    1.833674         floors
# 4                    1.202244     waterfront
# 5                    1.406680           view
# 6                    6.552083     sqft_above
# 7                    1.024762   yr_renovated
# 8                    1.271447        zipcode
# 9                    1.121038            lat
# 10                   2.673449  sqft_living15
# 11                   1.084918     sqft_lot15

# %%
house.duplicated().sum()
# Out:
# np.int64(5)

# %%
house.drop_duplicates(inplace=True)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaler,y,test_size=0.2,random_state=101)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_test=lr.predict(x_test)
y_pred_train=lr.predict(x_train)

# %%
from sklearn.metrics import r2_score

# %%
print("Training Accuracy ", r2_score(y_train, y_pred_train))
print("****************"*10)
print("Test Accuracy ", r2_score(y_test, y_pred_test))
# Out:
# Training Accuracy  0.6369300127502908
# ****************************************************************************************************************************************************************
# Test Accuracy  0.6565838330154805

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(x_train, y_train)
train_acc = rf.score(x_train, y_train)
test_acc = rf.score(x_test, y_test)
print(f"Training Accuracy: {train_acc}")
print(f"Test Accuracy: {test_acc}")
# Out:
# Training Accuracy: 0.9774457053072847
# Test Accuracy: 0.8516914802438356

# %%
from sklearn.model_selection import cross_val_score
training_acc= cross_val_score(rf,x_train,y_train,cv=10)
test_acc= cross_val_score(rf,x_test,y_test,cv=10)
print(f"Training Accuracy: {training_acc.mean()}")
print(f"Test Accuracy: {test_acc.mean()}")
# Out:
# Training Accuracy: 0.8358103101296687
# Test Accuracy: 0.7847342864240051
